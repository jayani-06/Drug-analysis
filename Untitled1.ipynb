# %%
pip install pandas scikit-learn joblib openpyxl

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score

from xgboost import XGBClassifier
import shap
import joblib

# %%
df = pd.read_excel("subset_data_ML.xlsx")

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (50, 35)
#    label       nct_id      i_id intervention_type           i_name  \
# 0      1  NCT00725270  12806562              Drug     Mifepristone
# 1      1  NCT00714259  12808076              Drug      Fludarabine
# 2      1  NCT01011478  12767281              Drug     rosuvastatin
# 3      1  NCT00697697  12810329              Drug  0.135mg MAP0010
# 4      1  NCT00697034  12810423              Drug        Capsaicin
#
#   drugbank id                                                smi  \
# 0     DB00834  [H][C@@]12CC[C@@](O)(C#CC)[C@@]1(C)C[C@H](C1=C...
# 1     DB01073  NC1=NC(F)=NC2=C1N=CN2[C@@H]1O[C@H](CO)[C@@H](O...
# 2     DB01098  CC(C)C1=NC(=NC(C2=CC=C(F)C=C2)=C1\C=C\[C@@H](O...
# 3     DB01222  [H][C@@]12C[C@H]3OC(CCC)O[C@@]3(C(=O)CO)[C@@]1...
# 4     DB06774            COC1=C(O)C=CC(CNC(=O)CCCC\C=C\C(C)C)=C1
#
#                             targets_drugbank  \
# 0  P07288,O75469,P06401,P04150,P06401,P04150
# 1      P27707,BE0004796,P23921,P09884,P27707
# ...

# %%
FEATURE_COLUMNS = [
    "tpsa",
    "n_rings",
    "n_rotatable_bonds",
    "num_of_atoms",
    "num_of_heavy_atoms",
    "num_heteroatoms",
    "h_donors",
    "h_acceptors",
    "gastiger_charges"
]

TARGET_COLUMN = "label"

X = df[FEATURE_COLUMNS]
y = df[TARGET_COLUMN]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    stratify=y,
    random_state=42
)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = XGBClassifier(
    n_estimators=120,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.85,
    colsample_bytree=0.85,
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42,
    tree_method="hist"
)

model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.85, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=120, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
print("Model expects features:", model.n_features_in_)
print("X has features:", X_train_scaled.shape[1])
# Out:
# Model expects features: 9
# X has features: 9

# %%
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# Accuracy: 0.46153846153846156
# ROC-AUC: 0.4285714285714286

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train_scaled)

shap.summary_plot(
    shap_values,
    X_train,
    feature_names=FEATURE_COLUMNS
)

# %%
joblib.dump(model, "drug_model.joblib")
joblib.dump(scaler, "scaler.joblib")
# Out:
# ['scaler.joblib']

# %%
import json

metadata = {
    "features": FEATURE_COLUMNS,
    "model_type": "XGBoost",
    "approval_threshold": 0.7,
    "trained_on": "subset_data_ML.xlsx"
}

with open("model_metadata.json", "w") as f:
    json.dump(metadata, f)

# %%
from google.colab import files

# %%
files.download("drug_model.joblib")
files.download("scaler.joblib")
files.download("model_metadata.json")
